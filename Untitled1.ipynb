# %% [markdown]
# last modified: 2020.11.23

# %% [markdown]
# # Odometry prediction from LiDAR Scan-Context Data
#
# 20204333 Kyuyeol Park

# %% [markdown]
# ## 1. Training (Supervised)

# %%
from q10Net import Q10Net
from sc_generation import Loader

net = Q10Net(model_type='mobilenetv2', input_shape=(320, 720, 2))
# Out:
# Using TensorFlow backend.
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ### training

# %%
train_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0028', data_type='raw',
                      batch_size=5, shuffle=True, load_type='train', val_ratio=0.3)
val_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0028', data_type='raw',
                    batch_size=5, shuffle=True, load_type='val', val_ratio=0.3)

net.train_real(train_loader, val_loader, epochs=20)
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0028
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0028
# Epoch 1/20
# 724/724 [==============================] - 180s 249ms/step - loss: 3.6490 - mae: 1.1709 - mse: 3.6490 - val_loss: 4.2506 - val_mae: 1.4850 - val_mse: 4.9415
# Epoch 2/20
# 724/724 [==============================] - 170s 235ms/step - loss: 1.6319 - mae: 0.8003 - mse: 1.6319 - val_loss: 10.5545 - val_mae: 1.8703 - val_mse: 8.4742
# Epoch 3/20
# 724/724 [==============================] - 170s 235ms/step - loss: 1.0741 - mae: 0.6599 - mse: 1.0741 - val_loss: 19.2228 - val_mae: 2.7263 - val_mse: 17.2178
# Epoch 4/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.8349 - mae: 0.5825 - mse: 0.8349 - val_loss: 12.1578 - val_mae: 2.1480 - val_mse: 11.4292
# Epoch 5/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.6935 - mae: 0.5328 - mse: 0.6935 - val_loss: 8.7673 - val_mae: 1.8128 - val_mse: 8.0635
# Epoch 6/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.5749 - mae: 0.4916 - mse: 0.5749 - val_loss: 1.9920 - val_mae: 1.2145 - val_mse: 3.2382
# Epoch 7/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.4787 - mae: 0.4522 - mse: 0.4787 - val_loss: 4.6785 - val_mae: 1.0378 - val_mse: 2.4661
# Epoch 8/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.4128 - mae: 0.4195 - mse: 0.4128 - val_loss: 1.6329 - val_mae: 0.7108 - val_mse: 1.4216
# Epoch 9/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.3840 - mae: 0.4036 - mse: 0.3840 - val_loss: 3.1669 - val_mae: 1.0858 - val_mse: 2.8833
# Epoch 10/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.3446 - mae: 0.3845 - mse: 0.3446 - val_loss: 0.8069 - val_mae: 0.6940 - val_mse: 1.1895
# Epoch 11/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.2967 - mae: 0.3617 - mse: 0.2967 - val_loss: 0.3160 - val_mae: 0.5310 - val_mse: 0.6648
# Epoch 12/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.2736 - mae: 0.3488 - mse: 0.2736 - val_loss: 6.8628 - val_mae: 1.6152 - val_mse: 6.2698
# Epoch 13/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.2413 - mae: 0.3303 - mse: 0.2413 - val_loss: 1.3721 - val_mae: 0.9145 - val_mse: 1.8887
# Epoch 14/20
# 724/724 [==============================] - 170s 234ms/step - loss: 0.2207 - mae: 0.3153 - mse: 0.2207 - val_loss: 3.0014 - val_mae: 0.9103 - val_mse: 1.9653
# Epoch 15/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.2025 - mae: 0.3037 - mse: 0.2025 - val_loss: 0.4168 - val_mae: 0.7220 - val_mse: 1.1859
# Epoch 16/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1927 - mae: 0.2965 - mse: 0.1927 - val_loss: 1.1606 - val_mae: 0.6857 - val_mse: 1.1039
# Epoch 17/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1803 - mae: 0.2887 - mse: 0.1803 - val_loss: 0.4418 - val_mae: 0.4145 - val_mse: 0.3561
# Epoch 18/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1689 - mae: 0.2770 - mse: 0.1689 - val_loss: 1.1079 - val_mae: 1.1758 - val_mse: 3.1535
# Epoch 19/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1584 - mae: 0.2679 - mse: 0.1584 - val_loss: 0.3924 - val_mae: 0.3867 - val_mse: 0.2990
# Epoch 20/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1469 - mae: 0.2588 - mse: 0.1469 - val_loss: 1.2851 - val_mae: 0.7948 - val_mse: 1.4735

# %% [markdown]
# ### eval

# %%
test_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0033', data_type='raw',
                     batch_size=5, shuffle=False, load_type='test')

net.eval(test_loader, save_dir='results/supervised.txt')
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0033
# 테스트 세트의 평균 절대 오차:  0.92
# 테스트 세트의 mse:  2.29

# %% [markdown]
# ## 2. Training (Self-supervised)

# %%
del net
net = Q10Net(model_type='mobilenetv2', input_shape=(320, 720, 2))

# %% [markdown]
# ### self-supervised training

# %%
train_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0028', data_type='aug',
                      batch_size=5, shuffle=True, load_type='train', val_ratio=0.3)
val_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0028', data_type='aug',
                    batch_size=5, shuffle=True, load_type='val', val_ratio=0.3)

net.train_self(train_loader, val_loader, epochs=20)
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0028
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0028
# Epoch 1/20
# 724/724 [==============================] - 177s 245ms/step - loss: 0.7360 - mae: 0.4305 - mse: 0.7360 - val_loss: 0.6339 - val_mae: 0.5942 - val_mse: 1.1085
# Epoch 2/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.5714 - mae: 0.3594 - mse: 0.5714 - val_loss: 1.0729 - val_mae: 0.5630 - val_mse: 1.0105
# Epoch 3/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.5552 - mae: 0.3429 - mse: 0.5552 - val_loss: 0.8605 - val_mae: 0.6074 - val_mse: 1.1110
# Epoch 4/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.5207 - mae: 0.3363 - mse: 0.5207 - val_loss: 1.1613 - val_mae: 0.7190 - val_mse: 1.4082
# Epoch 5/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.3872 - mae: 0.2934 - mse: 0.3872 - val_loss: 2.6926 - val_mae: 1.0014 - val_mse: 2.7452
# Epoch 6/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.3439 - mae: 0.2672 - mse: 0.3439 - val_loss: 1.1319 - val_mae: 0.7880 - val_mse: 1.8150
# Epoch 7/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.3286 - mae: 0.2574 - mse: 0.3286 - val_loss: 0.7773 - val_mae: 0.4808 - val_mse: 0.7004
# Epoch 8/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.1998 - mae: 0.2152 - mse: 0.1998 - val_loss: 0.2020 - val_mae: 0.2369 - val_mse: 0.2075
# Epoch 9/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1205 - mae: 0.1747 - mse: 0.1205 - val_loss: 0.3497 - val_mae: 0.3386 - val_mse: 0.4369
# Epoch 10/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.0961 - mae: 0.1577 - mse: 0.0961 - val_loss: 0.1226 - val_mae: 0.2425 - val_mse: 0.2363
# Epoch 11/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.0850 - mae: 0.1491 - mse: 0.0850 - val_loss: 0.1005 - val_mae: 0.3090 - val_mse: 0.3421
# Epoch 12/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.0745 - mae: 0.1397 - mse: 0.0745 - val_loss: 0.5185 - val_mae: 0.3442 - val_mse: 0.4357
# Epoch 13/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.0708 - mae: 0.1381 - mse: 0.0708 - val_loss: 1.1451 - val_mae: 0.4421 - val_mse: 0.7452
# Epoch 14/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.0595 - mae: 0.1268 - mse: 0.0595 - val_loss: 0.1098 - val_mae: 0.2721 - val_mse: 0.2795
# Epoch 15/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.0570 - mae: 0.1232 - mse: 0.0570 - val_loss: 0.0494 - val_mae: 0.1583 - val_mse: 0.1012
# Epoch 16/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.0534 - mae: 0.1184 - mse: 0.0534 - val_loss: 0.1322 - val_mae: 0.1784 - val_mse: 0.1214
# Epoch 17/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.0492 - mae: 0.1128 - mse: 0.0492 - val_loss: 0.2214 - val_mae: 0.1480 - val_mse: 0.1080
# Epoch 18/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.0468 - mae: 0.1101 - mse: 0.0468 - val_loss: 0.1522 - val_mae: 0.2708 - val_mse: 0.3181
# Epoch 19/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.0417 - mae: 0.1037 - mse: 0.0417 - val_loss: 0.1268 - val_mae: 0.2013 - val_mse: 0.1585
# Epoch 20/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.0376 - mae: 0.0994 - mse: 0.0376 - val_loss: 0.1413 - val_mae: 0.1626 - val_mse: 0.1229

# %% [markdown]
# ### transfer & fine-tune

# %%
train_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0028', data_type='raw',
                      batch_size=5, shuffle=True, load_type='train', val_ratio=0.3)
val_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0028', data_type='raw',
                    batch_size=5, shuffle=True, load_type='val', val_ratio=0.3)

net.fine_tune(train_loader, val_loader, epochs=10)
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0028
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0028
# Epoch 1/10
# 724/724 [==============================] - 38s 53ms/step - loss: 4.7011 - mae: 1.3112 - mse: 4.7011 - val_loss: 1.8714 - val_mae: 1.1472 - val_mse: 3.4784
# Epoch 2/10
# 724/724 [==============================] - 37s 51ms/step - loss: 3.5572 - mae: 1.1304 - mse: 3.5572 - val_loss: 26.6516 - val_mae: 3.0399 - val_mse: 20.9625
# Epoch 3/10
# 724/724 [==============================] - 37s 51ms/step - loss: 3.4091 - mae: 1.1007 - mse: 3.4091 - val_loss: 7.8302 - val_mae: 1.7173 - val_mse: 7.0844
# Epoch 4/10
# 724/724 [==============================] - 37s 51ms/step - loss: 3.2683 - mae: 1.0844 - mse: 3.2683 - val_loss: 4.1293 - val_mae: 1.4108 - val_mse: 4.9626
# Epoch 5/10
# 724/724 [==============================] - 37s 51ms/step - loss: 3.1555 - mae: 1.0767 - mse: 3.1555 - val_loss: 12.6684 - val_mae: 2.2056 - val_mse: 11.4206
# Epoch 6/10
# 724/724 [==============================] - 37s 51ms/step - loss: 3.0982 - mae: 1.0563 - mse: 3.0982 - val_loss: 3.9720 - val_mae: 1.0461 - val_mse: 2.9319
# Epoch 7/10
# 724/724 [==============================] - 37s 51ms/step - loss: 3.0573 - mae: 1.0511 - mse: 3.0573 - val_loss: 0.4836 - val_mae: 1.7642 - val_mse: 7.4301
# Epoch 8/10
# 724/724 [==============================] - 37s 51ms/step - loss: 2.8953 - mae: 1.0287 - mse: 2.8953 - val_loss: 5.3563 - val_mae: 1.6601 - val_mse: 7.0795
# Epoch 9/10
# 724/724 [==============================] - 37s 51ms/step - loss: 2.9344 - mae: 1.0275 - mse: 2.9344 - val_loss: 4.6082 - val_mae: 1.1423 - val_mse: 3.2750
# Epoch 10/10
# 724/724 [==============================] - 38s 52ms/step - loss: 2.8319 - mae: 1.0103 - mse: 2.8319 - val_loss: 6.0033 - val_mae: 1.7280 - val_mse: 7.6296

# %%
net.train_real(train_loader, val_loader, epochs=20)
# Out:
# Epoch 1/20
# 724/724 [==============================] - 177s 244ms/step - loss: 1.8812 - mae: 0.8097 - mse: 1.8812 - val_loss: 4.7094 - val_mae: 1.3012 - val_mse: 4.8001
# Epoch 2/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.9323 - mae: 0.5982 - mse: 0.9323 - val_loss: 6.8178 - val_mae: 1.7239 - val_mse: 6.9589
# Epoch 3/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.7157 - mae: 0.5269 - mse: 0.7157 - val_loss: 11.4363 - val_mae: 2.7727 - val_mse: 16.4833
# Epoch 4/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.5635 - mae: 0.4712 - mse: 0.5635 - val_loss: 2.6333 - val_mae: 1.1411 - val_mse: 2.9305
# Epoch 5/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.4568 - mae: 0.4291 - mse: 0.4568 - val_loss: 0.4170 - val_mae: 0.8218 - val_mse: 1.6235
# Epoch 6/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.4149 - mae: 0.4092 - mse: 0.4149 - val_loss: 0.6688 - val_mae: 0.5484 - val_mse: 0.7331
# Epoch 7/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.3520 - mae: 0.3809 - mse: 0.3520 - val_loss: 2.2638 - val_mae: 1.2625 - val_mse: 3.3576
# Epoch 8/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.3250 - mae: 0.3636 - mse: 0.3250 - val_loss: 3.1469 - val_mae: 1.1649 - val_mse: 3.0168
# Epoch 9/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.2822 - mae: 0.3438 - mse: 0.2822 - val_loss: 2.1356 - val_mae: 0.6623 - val_mse: 1.1016
# Epoch 10/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.2629 - mae: 0.3300 - mse: 0.2629 - val_loss: 0.4307 - val_mae: 0.4757 - val_mse: 0.5912
# Epoch 11/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.2439 - mae: 0.3189 - mse: 0.2439 - val_loss: 0.2465 - val_mae: 0.3727 - val_mse: 0.2897
# Epoch 12/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.2267 - mae: 0.3089 - mse: 0.2267 - val_loss: 0.8154 - val_mae: 0.6549 - val_mse: 0.9681
# Epoch 13/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.2093 - mae: 0.2987 - mse: 0.2093 - val_loss: 0.1384 - val_mae: 0.4057 - val_mse: 0.3599
# Epoch 14/20
# 724/724 [==============================] - 169s 233ms/step - loss: 0.1920 - mae: 0.2876 - mse: 0.1920 - val_loss: 0.3030 - val_mae: 0.3486 - val_mse: 0.3222
# Epoch 15/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.1779 - mae: 0.2770 - mse: 0.1779 - val_loss: 0.3282 - val_mae: 0.4847 - val_mse: 0.6072
# Epoch 16/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.1676 - mae: 0.2672 - mse: 0.1676 - val_loss: 0.5454 - val_mae: 0.5288 - val_mse: 0.6030
# Epoch 17/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.1629 - mae: 0.2674 - mse: 0.1629 - val_loss: 0.1807 - val_mae: 0.3467 - val_mse: 0.2499
# Epoch 18/20
# 724/724 [==============================] - 168s 232ms/step - loss: 0.1488 - mae: 0.2541 - mse: 0.1488 - val_loss: 0.4806 - val_mae: 0.4088 - val_mse: 0.4029
# Epoch 19/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.1411 - mae: 0.2479 - mse: 0.1411 - val_loss: 0.4494 - val_mae: 0.3649 - val_mse: 0.2395
# Epoch 20/20
# 724/724 [==============================] - 168s 233ms/step - loss: 0.1390 - mae: 0.2476 - mse: 0.1390 - val_loss: 1.0677 - val_mae: 0.5387 - val_mse: 0.6653

# %% [markdown]
# ### eval

# %%
test_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0033', data_type='raw',
                     batch_size=5, shuffle=False, load_type='test')

net.eval(test_loader, save_dir='results/self_supervised.txt')
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0033
# 테스트 세트의 평균 절대 오차:  0.85
# 테스트 세트의 mse:  2.29

# %%
net.model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 320, 720, 2)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 321, 721, 2)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 160, 360, 32) 576         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 160, 360, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 160, 360, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 160, 360, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 160, 360, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 160, 360, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 160, 360, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 160, 360, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 160, 360, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 160, 360, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 160, 360, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 161, 361, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 80, 180, 96)  864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 80, 180, 96)  384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 80, 180, 96)  0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 80, 180, 24)  2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 80, 180, 24)  96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 80, 180, 144) 3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 80, 180, 144) 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 80, 180, 144) 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 80, 180, 144) 1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 80, 180, 144) 576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 80, 180, 144) 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 80, 180, 24)  3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 80, 180, 24)  96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 80, 180, 24)  0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 80, 180, 144) 3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 80, 180, 144) 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 80, 180, 144) 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 81, 181, 144) 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 40, 90, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 40, 90, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 40, 90, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 40, 90, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 40, 90, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 40, 90, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 40, 90, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 40, 90, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 40, 90, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 40, 90, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 40, 90, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 40, 90, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 40, 90, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 40, 90, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 40, 90, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 40, 90, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 40, 90, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 40, 90, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 40, 90, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 40, 90, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 41, 91, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 20, 45, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 20, 45, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 20, 45, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 20, 45, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 20, 45, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 20, 45, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 20, 45, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 20, 45, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 20, 45, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 20, 45, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 20, 45, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 20, 45, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 20, 45, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 20, 45, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 20, 45, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 20, 45, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 20, 45, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 20, 45, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 20, 45, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 20, 45, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 20, 45, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 20, 45, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 20, 45, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 20, 45, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 20, 45, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 20, 45, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 20, 45, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 20, 45, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 20, 45, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 20, 45, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 20, 45, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 20, 45, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 20, 45, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 20, 45, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 20, 45, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 20, 45, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 20, 45, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 20, 45, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 20, 45, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 20, 45, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 21, 47, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 10, 23, 576)  5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 10, 23, 576)  2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 10, 23, 576)  0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 10, 23, 160)  92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 10, 23, 160)  640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 10, 23, 960)  153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 10, 23, 160)  153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 10, 23, 160)  640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 10, 23, 160)  0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 10, 23, 960)  153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 10, 23, 160)  153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 10, 23, 160)  640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 10, 23, 160)  0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 10, 23, 960)  153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 10, 23, 320)  307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 10, 23, 320)  1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 10, 23, 1280) 409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 10, 23, 1280) 5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 10, 23, 1280) 0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         1311744     global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 2)            2050        dense_7[0][0]
# ==================================================================================================
# Total params: 3,571,490
# Trainable params: 3,537,378
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.imshow(test_loader[20][0][0][:, :, 0])
plt.xlabel("sector")
plt.ylabel("ring")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(test_loader[20][0][0][:, :, 1])
plt.xlabel("sector")
plt.ylabel("ring")
plt.show()

# %%
test_loader[0][0][0].shape
# Out:
# (320, 720, 2)

# %%
import pykitti
import numpy as np

from utils import lla_to_enu

# kitti dataset
dataset = pykitti.raw('/datasets/kitti/raw', '2011_09_30', '0033')

gt_trajectory_lla = []  # [longitude(deg), latitude(deg), altitude(meter)] x N
gt_yaws = []  # [yaw_angle(rad),] x N
gt_yaw_rates = []  # [vehicle_yaw_rate(rad/s),] x N
gt_forward_velocities = []  # [vehicle_forward_velocity(m/s),] x N

for oxts_data in dataset.oxts:
    packet = oxts_data.packet
    gt_trajectory_lla.append([
        packet.lon,
        packet.lat,
        packet.alt
    ])
    gt_yaws.append(packet.yaw)
    gt_yaw_rates.append(packet.wz)
    gt_forward_velocities.append(packet.vf)

gt_trajectory_lla = np.array(gt_trajectory_lla).T
gt_yaws = np.array(gt_yaws)
gt_yaw_rates = np.array(gt_yaw_rates)
gt_forward_velocities = np.array(gt_forward_velocities)

timestamps = np.array(dataset.timestamps)
elapsed = np.array(timestamps) - timestamps[0]
ts = np.array([t.total_seconds() for t in elapsed])

# pre-processing: gps pose
origin = gt_trajectory_lla[:, 0]  # set the initial position to the origin
gt_trajectory_xyz = lla_to_enu(gt_trajectory_lla, origin)

lidar_points = dataset.velo

# %%
plt.plot(gt_trajectory_xyz[0, :], gt_trajectory_xyz[1, :])
plt.xlabel("X [m]")
plt.ylabel("Y [m]")
plt.show()

# %%
gt_trajectory_xyz.shape
# Out:
# (3, 1594)

# %%
import pickle

with open('results/self_supervised.txt', 'rb') as file:
    self_supervised_results = pickle.load(file)
    
with open('results/supervised.txt', 'rb') as file:
    supervised_results = pickle.load(file)

# %%
self_supervised_results
# Out:
# [array([[-0.        ,  0.        ],
#         [-0.01773688,  0.30696125],
#         [-0.03386297,  0.5860456 ],
#         ...,
#         [ 0.05251767,  7.1578035 ],
#         [ 0.06313365,  7.09104029],
#         [ 0.07044592,  7.05334334]]),
#  array([[ 0.01820674,  8.531207  ],
#         [ 0.03217751,  8.372402  ],
#         [ 0.08326569,  7.674352  ],
#         ...,
#         [ 0.07085654, 10.345383  ],
#         [ 0.09654614,  9.402738  ],
#         [ 0.07115179,  9.207208  ]], dtype=float32)]

# %%
train_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='raw',
                      batch_size=5, shuffle=True, load_type='train', val_ratio=0.3)
val_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='raw',
                    batch_size=5, shuffle=True, load_type='val', val_ratio=0.3)

net.train_real(train_loader, val_loader, epochs=3)
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# Epoch 1/3
# 39/39 [==============================] - 19s 497ms/step - loss: 10.3601 - mae: 2.1508 - mse: 10.3601 - val_loss: 105.7128 - val_mae: 7.0201 - val_mse: 100.8456
# Epoch 2/3
# 39/39 [==============================] - 9s 232ms/step - loss: 4.8634 - mae: 1.5863 - mse: 4.8634 - val_loss: 111.9582 - val_mae: 6.9386 - val_mse: 98.2903
# Epoch 3/3
# 39/39 [==============================] - 10s 254ms/step - loss: 3.6547 - mae: 1.4078 - mse: 3.6547 - val_loss: 98.7380 - val_mae: 6.8902 - val_mse: 97.0678

# %%
test_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='raw',
                     batch_size=5, shuffle=False, load_type='test')

net.eval(test_loader, save_dir='results/supervised.txt')
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# 테스트 세트의 평균 절대 오차:  6.93
# 테스트 세트의 mse: 97.76

# %%
import os
import tensorflow as tf
import keras.backend.tensorflow_backend as KK

config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
session = tf.compat.v1.Session(config=config)
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
from q10Net import Q10Net
from sc_generation import Loader

train_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='raw',
                      batch_size=5, shuffle=True, load_type='train', val_ratio=0.3)
val_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='raw',
                    batch_size=5, shuffle=True, load_type='val', val_ratio=0.3)

net = Q10Net(model_type='mobilenetv2', num_output=2, input_shape=(320, 720, 2))
# Out:
# Using TensorFlow backend.
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 720, 2)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 321, 721, 2)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 160, 360, 32) 576         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 160, 360, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 160, 360, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 160, 360, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 160, 360, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 160, 360, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 160, 360, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 160, 360, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 160, 360, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 160, 360, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 160, 360, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 161, 361, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 80, 180, 96)  864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 80, 180, 96)  384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 80, 180, 96)  0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 80, 180, 24)  2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 80, 180, 24)  96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 80, 180, 144) 3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 80, 180, 144) 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 80, 180, 144) 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 80, 180, 144) 1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 80, 180, 144) 576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 80, 180, 144) 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 80, 180, 24)  3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 80, 180, 24)  96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 80, 180, 24)  0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 80, 180, 144) 3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 80, 180, 144) 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 80, 180, 144) 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 81, 181, 144) 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 40, 90, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 40, 90, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 40, 90, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 40, 90, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 40, 90, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 40, 90, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 40, 90, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 40, 90, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 40, 90, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 40, 90, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 40, 90, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 40, 90, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 40, 90, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 40, 90, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 40, 90, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 40, 90, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 40, 90, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 40, 90, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 40, 90, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 40, 90, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 41, 91, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 20, 45, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 20, 45, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 20, 45, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 20, 45, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 20, 45, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 20, 45, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 20, 45, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 20, 45, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 20, 45, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 20, 45, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 20, 45, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 20, 45, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 20, 45, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 20, 45, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 20, 45, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 20, 45, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 20, 45, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 20, 45, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 20, 45, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 20, 45, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 20, 45, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 20, 45, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 20, 45, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 20, 45, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 20, 45, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 20, 45, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 20, 45, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 20, 45, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 20, 45, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 20, 45, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 20, 45, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 20, 45, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 20, 45, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 20, 45, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 20, 45, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 20, 45, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 20, 45, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 20, 45, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 20, 45, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 20, 45, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 21, 47, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 10, 23, 576)  5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 10, 23, 576)  2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 10, 23, 576)  0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 10, 23, 160)  92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 10, 23, 160)  640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 10, 23, 960)  153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 10, 23, 160)  153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 10, 23, 160)  640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 10, 23, 160)  0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 10, 23, 960)  153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 10, 23, 160)  153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 10, 23, 160)  640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 10, 23, 160)  0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 10, 23, 960)  153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 10, 23, 320)  307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 10, 23, 320)  1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 10, 23, 1280) 409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 10, 23, 1280) 5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 10, 23, 1280) 0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1311744     global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            2050        dense_1[0][0]
# ==================================================================================================
# Total params: 3,571,490
# Trainable params: 3,537,378
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
train_steps = train_loader.get_steps()
val_steps = val_loader.get_steps()

net.train(train_loader, val_loader, train_steps=train_steps, valid_steps=val_steps, epochs=100)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 20s 505ms/step - loss: 10.3217 - mae: 2.1385 - mse: 10.3217 - val_loss: 104.8565 - val_mae: 6.9947 - val_mse: 100.0164
# Epoch 2/100
# 39/39 [==============================] - 9s 230ms/step - loss: 5.3582 - mae: 1.7426 - mse: 5.3582 - val_loss: 97.7489 - val_mae: 6.8420 - val_mse: 95.7610
# Epoch 3/100
# 39/39 [==============================] - 9s 230ms/step - loss: 5.1376 - mae: 1.5238 - mse: 5.1376 - val_loss: 96.9276 - val_mae: 6.7987 - val_mse: 94.3138
# Epoch 4/100
# 39/39 [==============================] - 9s 232ms/step - loss: 3.2167 - mae: 1.2922 - mse: 3.2167 - val_loss: 89.2175 - val_mae: 6.6259 - val_mse: 89.7477
# Epoch 5/100
# 39/39 [==============================] - 9s 232ms/step - loss: 2.7326 - mae: 1.1463 - mse: 2.7326 - val_loss: 95.9350 - val_mae: 6.5150 - val_mse: 86.6151
# Epoch 6/100
# 39/39 [==============================] - 9s 231ms/step - loss: 2.4620 - mae: 1.1443 - mse: 2.4620 - val_loss: 82.4046 - val_mae: 6.3110 - val_mse: 81.4497
# Epoch 7/100
# 39/39 [==============================] - 9s 233ms/step - loss: 2.4325 - mae: 1.0056 - mse: 2.4325 - val_loss: 89.2989 - val_mae: 6.4346 - val_mse: 84.3175
# Epoch 8/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.7307 - mae: 0.8942 - mse: 1.7307 - val_loss: 78.5673 - val_mae: 6.1812 - val_mse: 77.1198
# Epoch 9/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.6883 - mae: 0.9044 - mse: 1.6883 - val_loss: 68.4397 - val_mae: 5.8368 - val_mse: 69.3226
# Epoch 10/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.3009 - mae: 0.8284 - mse: 1.3009 - val_loss: 54.7311 - val_mae: 5.7479 - val_mse: 65.6434
# Epoch 11/100
# 39/39 [==============================] - 9s 232ms/step - loss: 1.2153 - mae: 0.7924 - mse: 1.2153 - val_loss: 70.5321 - val_mae: 5.6336 - val_mse: 64.9405
# Epoch 12/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.1608 - mae: 0.7907 - mse: 1.1608 - val_loss: 40.2031 - val_mae: 5.1896 - val_mse: 54.7938
# Epoch 13/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.3669 - mae: 0.7280 - mse: 1.3669 - val_loss: 65.2304 - val_mae: 5.6500 - val_mse: 63.5705
# Epoch 14/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.0824 - mae: 0.7408 - mse: 1.0824 - val_loss: 50.9976 - val_mae: 4.8241 - val_mse: 46.7811
# Epoch 15/100
# 39/39 [==============================] - 9s 232ms/step - loss: 1.1186 - mae: 0.7286 - mse: 1.1186 - val_loss: 46.0367 - val_mae: 4.8079 - val_mse: 45.9336
# Epoch 16/100
# 39/39 [==============================] - 9s 232ms/step - loss: 1.0712 - mae: 0.6482 - mse: 1.0712 - val_loss: 48.4353 - val_mae: 5.1461 - val_mse: 53.4550
# Epoch 17/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.6086 - mae: 0.5747 - mse: 0.6086 - val_loss: 41.7665 - val_mae: 4.6661 - val_mse: 42.7155
# Epoch 18/100
# 39/39 [==============================] - 9s 233ms/step - loss: 1.2705 - mae: 0.6943 - mse: 1.2705 - val_loss: 43.8368 - val_mae: 4.7956 - val_mse: 45.6609
# Epoch 19/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.9664 - mae: 0.6427 - mse: 0.9664 - val_loss: 35.3146 - val_mae: 4.5000 - val_mse: 40.2987
# Epoch 20/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.7160 - mae: 0.5260 - mse: 0.7160 - val_loss: 41.7402 - val_mae: 4.5577 - val_mse: 41.0096
# Epoch 21/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.8598 - mae: 0.6331 - mse: 0.8598 - val_loss: 41.1877 - val_mae: 4.1275 - val_mse: 34.3399
# Epoch 22/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.6862 - mae: 0.5535 - mse: 0.6862 - val_loss: 42.7098 - val_mae: 4.7789 - val_mse: 45.6547
# Epoch 23/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.8245 - mae: 0.5985 - mse: 0.8245 - val_loss: 26.7543 - val_mae: 4.0305 - val_mse: 33.1315
# Epoch 24/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.7777 - mae: 0.5973 - mse: 0.7777 - val_loss: 25.1513 - val_mae: 3.5994 - val_mse: 26.7286
# Epoch 25/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.8243 - mae: 0.5796 - mse: 0.8243 - val_loss: 38.6571 - val_mae: 3.8910 - val_mse: 29.4060
# Epoch 26/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.7235 - mae: 0.5681 - mse: 0.7235 - val_loss: 29.0705 - val_mae: 3.5673 - val_mse: 24.7861
# Epoch 27/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.5840 - mae: 0.5563 - mse: 0.5840 - val_loss: 34.9861 - val_mae: 4.0576 - val_mse: 33.4313
# Epoch 28/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.6235 - mae: 0.5633 - mse: 0.6235 - val_loss: 28.6351 - val_mae: 3.9415 - val_mse: 29.8937
# Epoch 29/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.6319 - mae: 0.5078 - mse: 0.6319 - val_loss: 31.5846 - val_mae: 3.8995 - val_mse: 29.5215
# Epoch 30/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.6382 - mae: 0.5373 - mse: 0.6382 - val_loss: 28.3317 - val_mae: 3.6353 - val_mse: 25.4282
# Epoch 31/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.6141 - mae: 0.4914 - mse: 0.6141 - val_loss: 28.3207 - val_mae: 3.7697 - val_mse: 27.2118
# Epoch 32/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.5600 - mae: 0.5022 - mse: 0.5600 - val_loss: 28.8457 - val_mae: 3.7946 - val_mse: 28.6127
# Epoch 33/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.6007 - mae: 0.5209 - mse: 0.6007 - val_loss: 12.4421 - val_mae: 2.7052 - val_mse: 14.6397
# Epoch 34/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.5916 - mae: 0.5536 - mse: 0.5916 - val_loss: 17.0422 - val_mae: 3.0298 - val_mse: 18.0471
# Epoch 35/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.5789 - mae: 0.5460 - mse: 0.5789 - val_loss: 20.2064 - val_mae: 2.9129 - val_mse: 16.4336
# Epoch 36/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.5825 - mae: 0.5502 - mse: 0.5825 - val_loss: 13.4308 - val_mae: 3.0924 - val_mse: 18.8680
# Epoch 37/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.5761 - mae: 0.5191 - mse: 0.5761 - val_loss: 26.6299 - val_mae: 3.5323 - val_mse: 24.8659
# Epoch 38/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.5444 - mae: 0.4727 - mse: 0.5444 - val_loss: 21.0215 - val_mae: 3.9017 - val_mse: 29.8315
# Epoch 39/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.4494 - mae: 0.4652 - mse: 0.4494 - val_loss: 20.5720 - val_mae: 3.3542 - val_mse: 22.0719
# Epoch 40/100
# 39/39 [==============================] - 10s 244ms/step - loss: 0.4912 - mae: 0.5236 - mse: 0.4912 - val_loss: 28.4528 - val_mae: 3.5489 - val_mse: 24.6065
# Epoch 41/100
# 39/39 [==============================] - 9s 236ms/step - loss: 0.4764 - mae: 0.4743 - mse: 0.4764 - val_loss: 25.0078 - val_mae: 3.2345 - val_mse: 20.6772
# Epoch 42/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.4905 - mae: 0.4700 - mse: 0.4905 - val_loss: 19.2600 - val_mae: 3.4637 - val_mse: 22.6390
# Epoch 43/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.5114 - mae: 0.5020 - mse: 0.5114 - val_loss: 18.4159 - val_mae: 3.2721 - val_mse: 21.0306
# Epoch 44/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.4131 - mae: 0.4407 - mse: 0.4131 - val_loss: 16.6624 - val_mae: 3.1501 - val_mse: 19.7059
# Epoch 45/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.4500 - mae: 0.4637 - mse: 0.4500 - val_loss: 23.5984 - val_mae: 3.5138 - val_mse: 24.8613
# Epoch 46/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.3519 - mae: 0.4261 - mse: 0.3519 - val_loss: 20.6797 - val_mae: 3.2914 - val_mse: 21.1825
# Epoch 47/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.4038 - mae: 0.4139 - mse: 0.4038 - val_loss: 17.3702 - val_mae: 3.2160 - val_mse: 19.7907
# Epoch 48/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.3630 - mae: 0.4080 - mse: 0.3630 - val_loss: 19.8455 - val_mae: 3.6349 - val_mse: 25.4580
# Epoch 49/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.4399 - mae: 0.4524 - mse: 0.4399 - val_loss: 15.2881 - val_mae: 2.9717 - val_mse: 17.9893
# Epoch 50/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.3909 - mae: 0.4206 - mse: 0.3909 - val_loss: 20.4603 - val_mae: 3.7356 - val_mse: 28.7029
# Epoch 51/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.4194 - mae: 0.4548 - mse: 0.4194 - val_loss: 20.0728 - val_mae: 2.9698 - val_mse: 17.9715
# Epoch 52/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.3250 - mae: 0.4017 - mse: 0.3250 - val_loss: 25.0214 - val_mae: 3.3913 - val_mse: 23.0816
# Epoch 53/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.4458 - mae: 0.4427 - mse: 0.4458 - val_loss: 21.7969 - val_mae: 3.3907 - val_mse: 22.8487
# Epoch 54/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.2693 - mae: 0.3793 - mse: 0.2693 - val_loss: 30.9080 - val_mae: 3.8301 - val_mse: 28.9871
# Epoch 55/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.4087 - mae: 0.4380 - mse: 0.4087 - val_loss: 30.4488 - val_mae: 3.6778 - val_mse: 27.1208
# Epoch 56/100
# 39/39 [==============================] - 9s 230ms/step - loss: 0.3529 - mae: 0.4175 - mse: 0.3529 - val_loss: 34.1511 - val_mae: 3.6966 - val_mse: 28.0083
# Epoch 57/100
# 39/39 [==============================] - 9s 230ms/step - loss: 0.3095 - mae: 0.3848 - mse: 0.3095 - val_loss: 27.1760 - val_mae: 3.5691 - val_mse: 26.1886
# Epoch 58/100
# 39/39 [==============================] - 9s 230ms/step - loss: 0.3862 - mae: 0.3893 - mse: 0.3862 - val_loss: 28.1173 - val_mae: 3.6340 - val_mse: 25.7086
# Epoch 59/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.3237 - mae: 0.4268 - mse: 0.3237 - val_loss: 27.3338 - val_mae: 3.6911 - val_mse: 27.2766
# Epoch 60/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.3076 - mae: 0.3745 - mse: 0.3076 - val_loss: 34.6722 - val_mae: 4.0478 - val_mse: 33.0703
# Epoch 61/100
# 39/39 [==============================] - 9s 236ms/step - loss: 0.3490 - mae: 0.3856 - mse: 0.3490 - val_loss: 25.2368 - val_mae: 3.6773 - val_mse: 26.8170
# Epoch 62/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.3072 - mae: 0.4148 - mse: 0.3072 - val_loss: 29.4271 - val_mae: 3.6550 - val_mse: 27.5761
# Epoch 63/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.2996 - mae: 0.3637 - mse: 0.2996 - val_loss: 21.6976 - val_mae: 3.6353 - val_mse: 27.0721
# Epoch 64/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.2719 - mae: 0.3591 - mse: 0.2719 - val_loss: 28.4840 - val_mae: 3.6547 - val_mse: 27.3783
# Epoch 65/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.2435 - mae: 0.3606 - mse: 0.2435 - val_loss: 24.1954 - val_mae: 3.9837 - val_mse: 31.9737
# Epoch 66/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.3290 - mae: 0.4157 - mse: 0.3290 - val_loss: 22.4603 - val_mae: 3.8921 - val_mse: 31.0335
# Epoch 67/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.2396 - mae: 0.3479 - mse: 0.2396 - val_loss: 33.7493 - val_mae: 3.8947 - val_mse: 31.0341
# Epoch 68/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.2871 - mae: 0.3668 - mse: 0.2871 - val_loss: 32.1621 - val_mae: 4.2582 - val_mse: 37.3559
# Epoch 69/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.2586 - mae: 0.3490 - mse: 0.2586 - val_loss: 42.2495 - val_mae: 3.9677 - val_mse: 32.3922
# Epoch 70/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.2443 - mae: 0.3843 - mse: 0.2443 - val_loss: 12.5003 - val_mae: 2.8048 - val_mse: 16.3687
# Epoch 71/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.2188 - mae: 0.3231 - mse: 0.2188 - val_loss: 26.3976 - val_mae: 3.5390 - val_mse: 24.7006
# Epoch 72/100
# 39/39 [==============================] - 9s 240ms/step - loss: 0.3253 - mae: 0.3974 - mse: 0.3253 - val_loss: 29.7253 - val_mae: 3.6738 - val_mse: 27.6354
# Epoch 73/100
# 39/39 [==============================] - 9s 241ms/step - loss: 0.1946 - mae: 0.3101 - mse: 0.1946 - val_loss: 22.1695 - val_mae: 3.0691 - val_mse: 19.0713
# Epoch 74/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.2269 - mae: 0.3398 - mse: 0.2269 - val_loss: 23.8783 - val_mae: 3.5615 - val_mse: 25.4458
# Epoch 75/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.2256 - mae: 0.3320 - mse: 0.2256 - val_loss: 24.6051 - val_mae: 3.7346 - val_mse: 28.3869
# Epoch 76/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.2552 - mae: 0.3287 - mse: 0.2552 - val_loss: 28.1813 - val_mae: 3.5921 - val_mse: 26.5807
# Epoch 77/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.2133 - mae: 0.3391 - mse: 0.2133 - val_loss: 18.2873 - val_mae: 3.1515 - val_mse: 19.9272
# Epoch 78/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.2121 - mae: 0.3040 - mse: 0.2121 - val_loss: 36.2303 - val_mae: 3.8924 - val_mse: 30.1513
# Epoch 79/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.2261 - mae: 0.3410 - mse: 0.2261 - val_loss: 23.4573 - val_mae: 3.3222 - val_mse: 21.7319
# Epoch 80/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.2378 - mae: 0.3242 - mse: 0.2378 - val_loss: 19.2659 - val_mae: 2.7891 - val_mse: 16.2609
# Epoch 81/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.1936 - mae: 0.3264 - mse: 0.1936 - val_loss: 17.9624 - val_mae: 2.9514 - val_mse: 18.0135
# Epoch 82/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.2447 - mae: 0.3300 - mse: 0.2447 - val_loss: 21.0713 - val_mae: 3.4671 - val_mse: 24.0906
# Epoch 83/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.2050 - mae: 0.3195 - mse: 0.2050 - val_loss: 12.2156 - val_mae: 2.7742 - val_mse: 16.0453
# Epoch 84/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.2280 - mae: 0.2999 - mse: 0.2280 - val_loss: 18.8806 - val_mae: 3.2959 - val_mse: 21.5864
# Epoch 85/100
# 39/39 [==============================] - 9s 236ms/step - loss: 0.1606 - mae: 0.3067 - mse: 0.1606 - val_loss: 26.8543 - val_mae: 3.4301 - val_mse: 23.1548
# Epoch 86/100
# 39/39 [==============================] - 9s 242ms/step - loss: 0.2227 - mae: 0.3210 - mse: 0.2227 - val_loss: 21.8275 - val_mae: 3.1184 - val_mse: 19.9139
# Epoch 87/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.2567 - mae: 0.3184 - mse: 0.2567 - val_loss: 27.7133 - val_mae: 3.2214 - val_mse: 21.3216
# Epoch 88/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.2250 - mae: 0.3433 - mse: 0.2250 - val_loss: 15.3279 - val_mae: 2.8697 - val_mse: 16.8812
# Epoch 89/100
# 39/39 [==============================] - 9s 240ms/step - loss: 0.1964 - mae: 0.2985 - mse: 0.1964 - val_loss: 13.1320 - val_mae: 2.8310 - val_mse: 16.0863
# Epoch 90/100
# 39/39 [==============================] - 9s 241ms/step - loss: 0.1916 - mae: 0.3090 - mse: 0.1916 - val_loss: 21.7155 - val_mae: 2.8597 - val_mse: 16.7664
# Epoch 91/100
# 39/39 [==============================] - 9s 236ms/step - loss: 0.2019 - mae: 0.3323 - mse: 0.2019 - val_loss: 15.8140 - val_mae: 3.3344 - val_mse: 22.3038
# Epoch 92/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.1761 - mae: 0.3037 - mse: 0.1761 - val_loss: 15.7142 - val_mae: 2.5677 - val_mse: 13.9223
# Epoch 93/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.2303 - mae: 0.3262 - mse: 0.2303 - val_loss: 19.9402 - val_mae: 2.9673 - val_mse: 17.8993
# Epoch 94/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.1669 - mae: 0.3087 - mse: 0.1669 - val_loss: 14.9760 - val_mae: 3.0230 - val_mse: 17.9124
# Epoch 95/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.1528 - mae: 0.2806 - mse: 0.1528 - val_loss: 18.5195 - val_mae: 2.7744 - val_mse: 14.9383
# Epoch 96/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.2180 - mae: 0.2975 - mse: 0.2180 - val_loss: 14.8226 - val_mae: 2.6834 - val_mse: 14.2832
# Epoch 97/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.1704 - mae: 0.3007 - mse: 0.1704 - val_loss: 13.3064 - val_mae: 2.6764 - val_mse: 14.9933
# Epoch 98/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.1663 - mae: 0.2926 - mse: 0.1663 - val_loss: 11.2579 - val_mae: 3.2096 - val_mse: 21.2429
# Epoch 99/100
# 39/39 [==============================] - 9s 231ms/step - loss: 0.2072 - mae: 0.3080 - mse: 0.2072 - val_loss: 20.0814 - val_mae: 3.0989 - val_mse: 18.4046
# Epoch 100/100
# 39/39 [==============================] - 9s 232ms/step - loss: 0.1518 - mae: 0.2860 - mse: 0.1518 - val_loss: 13.7759 - val_mae: 2.4876 - val_mse: 12.8664

# %%
train_loader[10][1]
# Out:
# array([[ 4.48058124e-03,  1.40747570e+01],
#        [-2.52476187e-03,  1.59484015e+01],
#        [ 8.41277576e-03,  1.54935162e+01],
#        [ 5.79724918e-04,  1.53092844e+01],
#        [ 6.22061397e-03,  1.42608304e+01]])

# %%
train_loader[30][1]
# Out:
# array([[-4.74026130e-03,  1.43153312e+01],
#        [ 2.34280165e-03,  1.39243117e+01],
#        [-9.05710134e-03,  1.53933190e+01],
#        [ 2.52358595e-03,  1.39878629e+01],
#        [ 1.10447694e-02,  1.42250131e+01]])

# %%
net.model.predict(train_loader[30][0])
# Out:
# array([[1.6471803e-02, 9.2700758e+00],
#        [1.5120223e-02, 9.2796335e+00],
#        [8.0425292e-03, 7.9808946e+00],
#        [1.3329446e-02, 9.1889505e+00],
#        [1.3880029e-02, 8.7809744e+00]], dtype=float32)

# %%
loss, mae, mse = net.model.evaluate_generator(train_loader, verbose=2)

print("테스트 세트의 평균 절대 오차: {:5.2f} MPG".format(mae))
print("테스트 세트의 mse: {:5.2f} MPG".format(mse))
# Out:
# 테스트 세트의 평균 절대 오차:  2.54 MPG
# 테스트 세트의 mse: 13.41 MPG

# %%
test_predictions = predicted_yaw
test_labels = gt_yaw

error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [MPG]")
_ = plt.ylabel("Count")

# %%
test_predictions = gt_dis
test_labels = predicted_dis

error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [MPG]")
_ = plt.ylabel("Count")

# %%
len(train_loader)
# Out:
# 39

# %%
test_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='raw',
                     batch_size=5, shuffle=False, load_type='test', val_ratio=0.0)
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016

# %%
import numpy as np

gt = []
predicted = []

for idx, batch in enumerate(train_loader):
    gt.append(batch[1])
    predicted.append(net.model.predict(batch[0]))
    
gt = np.array(gt)
predicted = np.array(predicted)

# %%
gt_yaw = np.reshape(gt, (-1, 2))[:, 0]
gt_dis = np.reshape(gt, (-1, 2))[:, 1]

predicted_yaw = np.reshape(predicted, (-1, 2))[:, 0]
predicted_dis = np.reshape(predicted, (-1, 2))[:, 1]

# %%
len(gt_yaw)
# Out:
# 195

# %%
asdf = net.model.predict_generator(train_loader, steps=train_loader.get_steps())

# %%
asdf.shape
# Out:
# (195, 2)

# %%
train_loader[:, :, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-57f01729c67f> in <module>
# ----> 1 train_loader[:, :, 0]
#
# ~/ws/repos/sc_odom/sc_generation.py in __getitem__(self, index)
#     385
#     386     def __getitem__(self, index):  # index : batch no.
# --> 387         indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
#     388         batch_ids = [self.ids[k] for k in indexes]
#     389
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(gt_yaw)), gt_yaw, label='gt_yaw')
plt.plot(range(len(predicted_yaw)), predicted_yaw, label='predicted_yaw')
plt.legend()
plt.show()

plt.plot(range(len(gt_dis)), gt_dis, label='gt_dis')
plt.plot(range(len(predicted_dis)), predicted_dis, label='predicted_dis')
plt.legend()
plt.show()

# %%
len(predicted_yaw)
# Out:
# 275

# %%
from q10Net import Q10Net
from sc_generation import Loader

train_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='aug',
                      batch_size=5, shuffle=True, load_type='train', val_ratio=0.3)
val_loader = Loader(kitti_root_dir='/datasets/kitti/raw', kitti_date='2011_09_30', kitti_drive='0016', data_type='aug',
                    batch_size=5, shuffle=True, load_type='val', val_ratio=0.3)

net = Q10Net(model_type='mobilenetv2', num_output=6, input_shape=(320, 720, 2))
# Out:
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# kitti dataset loaded: /datasets/kitti/raw_2011_09_30_0016
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 320, 720, 2)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 321, 721, 2)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 160, 360, 32) 576         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 160, 360, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 160, 360, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 160, 360, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 160, 360, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 160, 360, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 160, 360, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 160, 360, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 160, 360, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 160, 360, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 160, 360, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 161, 361, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 80, 180, 96)  864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 80, 180, 96)  384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 80, 180, 96)  0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 80, 180, 24)  2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 80, 180, 24)  96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 80, 180, 144) 3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 80, 180, 144) 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 80, 180, 144) 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 80, 180, 144) 1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 80, 180, 144) 576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 80, 180, 144) 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 80, 180, 24)  3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 80, 180, 24)  96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 80, 180, 24)  0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 80, 180, 144) 3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 80, 180, 144) 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 80, 180, 144) 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 81, 181, 144) 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 40, 90, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 40, 90, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 40, 90, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 40, 90, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 40, 90, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 40, 90, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 40, 90, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 40, 90, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 40, 90, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 40, 90, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 40, 90, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 40, 90, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 40, 90, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 40, 90, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 40, 90, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 40, 90, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 40, 90, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 40, 90, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 40, 90, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 40, 90, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 40, 90, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 40, 90, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 41, 91, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 20, 45, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 20, 45, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 20, 45, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 20, 45, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 20, 45, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 20, 45, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 20, 45, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 20, 45, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 20, 45, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 20, 45, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 20, 45, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 20, 45, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 20, 45, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 20, 45, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 20, 45, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 20, 45, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 20, 45, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 20, 45, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 20, 45, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 20, 45, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 20, 45, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 20, 45, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 20, 45, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 20, 45, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 20, 45, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 20, 45, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 20, 45, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 20, 45, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 20, 45, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 20, 45, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 20, 45, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 20, 45, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 20, 45, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 20, 45, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 20, 45, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 20, 45, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 20, 45, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 20, 45, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 20, 45, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 20, 45, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 20, 45, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 20, 45, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 20, 45, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 20, 45, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 20, 45, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 20, 45, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 20, 45, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 21, 47, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 10, 23, 576)  5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 10, 23, 576)  2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 10, 23, 576)  0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 10, 23, 160)  92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 10, 23, 160)  640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 10, 23, 960)  153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 10, 23, 160)  153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 10, 23, 160)  640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 10, 23, 160)  0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 10, 23, 960)  153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 10, 23, 160)  153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 10, 23, 160)  640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 10, 23, 160)  0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 10, 23, 960)  153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 10, 23, 960)  3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 10, 23, 960)  0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 10, 23, 960)  8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 10, 23, 960)  3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 10, 23, 960)  0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 10, 23, 320)  307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 10, 23, 320)  1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 10, 23, 1280) 409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 10, 23, 1280) 5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 10, 23, 1280) 0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         1311744     global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 6)            6150        dense_3[0][0]
# ==================================================================================================
# Total params: 3,575,590
# Trainable params: 3,541,478
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
train_steps = train_loader.get_steps()
val_steps = val_loader.get_steps()

net.train(train_loader, val_loader, train_steps=train_steps, valid_steps=val_steps, epochs=100)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 20s 518ms/step - loss: 2.9660 - mae: 0.7828 - mse: 2.9660 - val_loss: 1.0886 - val_mae: 0.3875 - val_mse: 0.6448
# Epoch 2/100
# 39/39 [==============================] - 9s 243ms/step - loss: 0.6801 - mae: 0.4846 - mse: 0.6801 - val_loss: 0.3199 - val_mae: 0.4063 - val_mse: 0.6761
# Epoch 3/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.6239 - mae: 0.4504 - mse: 0.6239 - val_loss: 0.9555 - val_mae: 0.4065 - val_mse: 0.6391
# Epoch 4/100
# 39/39 [==============================] - 10s 251ms/step - loss: 0.5796 - mae: 0.4181 - mse: 0.5796 - val_loss: 0.7036 - val_mae: 0.4412 - val_mse: 0.6873
# Epoch 5/100
# 39/39 [==============================] - 10s 252ms/step - loss: 0.5725 - mae: 0.4073 - mse: 0.5725 - val_loss: 0.3388 - val_mae: 0.4166 - val_mse: 0.6309
# Epoch 6/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.5504 - mae: 0.4033 - mse: 0.5504 - val_loss: 0.9109 - val_mae: 0.4940 - val_mse: 0.7231
# Epoch 7/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.5720 - mae: 0.4147 - mse: 0.5720 - val_loss: 0.9923 - val_mae: 0.4638 - val_mse: 0.7006
# Epoch 8/100
# 39/39 [==============================] - 10s 244ms/step - loss: 0.5533 - mae: 0.3909 - mse: 0.5533 - val_loss: 0.4616 - val_mae: 0.4830 - val_mse: 0.7291
# Epoch 9/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.5359 - mae: 0.3833 - mse: 0.5359 - val_loss: 0.4320 - val_mae: 0.4626 - val_mse: 0.6824
# Epoch 10/100
# 39/39 [==============================] - 9s 239ms/step - loss: 0.5433 - mae: 0.3826 - mse: 0.5433 - val_loss: 1.1634 - val_mae: 0.4799 - val_mse: 0.7462
# Epoch 11/100
# 39/39 [==============================] - 9s 239ms/step - loss: 0.5165 - mae: 0.3701 - mse: 0.5165 - val_loss: 0.6567 - val_mae: 0.4476 - val_mse: 0.6893
# Epoch 12/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.5325 - mae: 0.3723 - mse: 0.5325 - val_loss: 0.4367 - val_mae: 0.5165 - val_mse: 0.8274
# Epoch 13/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.5087 - mae: 0.3645 - mse: 0.5087 - val_loss: 0.8729 - val_mae: 0.4804 - val_mse: 0.7275
# Epoch 14/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.5228 - mae: 0.3628 - mse: 0.5228 - val_loss: 0.7025 - val_mae: 0.5382 - val_mse: 0.8592
# Epoch 15/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.5336 - mae: 0.3638 - mse: 0.5336 - val_loss: 0.8895 - val_mae: 0.5601 - val_mse: 0.9474
# Epoch 16/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.5084 - mae: 0.3561 - mse: 0.5084 - val_loss: 0.8305 - val_mae: 0.5229 - val_mse: 0.8298
# Epoch 17/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.5085 - mae: 0.3528 - mse: 0.5085 - val_loss: 0.5907 - val_mae: 0.5506 - val_mse: 0.8113
# Epoch 18/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.5285 - mae: 0.3655 - mse: 0.5285 - val_loss: 0.6007 - val_mae: 0.5602 - val_mse: 0.8795
# Epoch 19/100
# 39/39 [==============================] - 9s 236ms/step - loss: 0.4987 - mae: 0.3508 - mse: 0.4987 - val_loss: 1.4320 - val_mae: 0.4922 - val_mse: 0.7261
# Epoch 20/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.4809 - mae: 0.3385 - mse: 0.4809 - val_loss: 0.7900 - val_mae: 0.5371 - val_mse: 0.8208
# Epoch 21/100
# 39/39 [==============================] - 9s 234ms/step - loss: 0.4846 - mae: 0.3448 - mse: 0.4846 - val_loss: 1.5889 - val_mae: 0.5744 - val_mse: 0.9399
# Epoch 22/100
# 39/39 [==============================] - 9s 236ms/step - loss: 0.4822 - mae: 0.3509 - mse: 0.4822 - val_loss: 1.1642 - val_mae: 0.5636 - val_mse: 0.8199
# Epoch 23/100
# 39/39 [==============================] - 9s 235ms/step - loss: 0.4747 - mae: 0.3436 - mse: 0.4747 - val_loss: 0.2030 - val_mae: 0.5148 - val_mse: 0.7781
# Epoch 24/100
# 39/39 [==============================] - 9s 239ms/step - loss: 0.4627 - mae: 0.3384 - mse: 0.4627 - val_loss: 1.0781 - val_mae: 0.5571 - val_mse: 0.8512
# Epoch 25/100
# 39/39 [==============================] - 9s 230ms/step - loss: 0.4523 - mae: 0.3422 - mse: 0.4523 - val_loss: 0.6457 - val_mae: 0.5656 - val_mse: 0.9084
# Epoch 26/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.4502 - mae: 0.3317 - mse: 0.4502 - val_loss: 1.3565 - val_mae: 0.5704 - val_mse: 0.9350
# Epoch 27/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.3949 - mae: 0.3150 - mse: 0.3949 - val_loss: 1.0521 - val_mae: 0.5834 - val_mse: 0.9226
# Epoch 28/100
# 39/39 [==============================] - 9s 233ms/step - loss: 0.3858 - mae: 0.3138 - mse: 0.3858 - val_loss: 1.0212 - val_mae: 0.6154 - val_mse: 1.0241
# Epoch 29/100
# 39/39 [==============================] - 10s 248ms/step - loss: 0.4135 - mae: 0.3143 - mse: 0.4135 - val_loss: 0.4855 - val_mae: 0.6434 - val_mse: 1.0721
# Epoch 30/100
# 39/39 [==============================] - 10s 250ms/step - loss: 0.4152 - mae: 0.3251 - mse: 0.4152 - val_loss: 0.9246 - val_mae: 0.6843 - val_mse: 1.2220
# Epoch 31/100
# 39/39 [==============================] - 9s 241ms/step - loss: 0.3738 - mae: 0.3087 - mse: 0.3738 - val_loss: 1.2859 - val_mae: 0.7235 - val_mse: 1.2847
# Epoch 32/100
# 39/39 [==============================] - 10s 244ms/step - loss: 0.3748 - mae: 0.3008 - mse: 0.3748 - val_loss: 1.3646 - val_mae: 0.8335 - val_mse: 1.6707
# Epoch 33/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.3875 - mae: 0.3067 - mse: 0.3875 - val_loss: 1.5817 - val_mae: 0.7548 - val_mse: 1.4306
# Epoch 34/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.3797 - mae: 0.3116 - mse: 0.3797 - val_loss: 0.7607 - val_mae: 0.7444 - val_mse: 1.3604
# Epoch 35/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.3584 - mae: 0.3036 - mse: 0.3584 - val_loss: 1.3986 - val_mae: 0.8423 - val_mse: 1.7016
# Epoch 36/100
# 39/39 [==============================] - 10s 244ms/step - loss: 0.3821 - mae: 0.3178 - mse: 0.3821 - val_loss: 1.4450 - val_mae: 0.7850 - val_mse: 1.5533
# Epoch 37/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.3010 - mae: 0.2798 - mse: 0.3010 - val_loss: 2.5502 - val_mae: 0.9167 - val_mse: 1.9904
# Epoch 38/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.3401 - mae: 0.2961 - mse: 0.3401 - val_loss: 1.8649 - val_mae: 0.9894 - val_mse: 2.2707
# Epoch 39/100
# 39/39 [==============================] - 9s 243ms/step - loss: 0.3282 - mae: 0.2879 - mse: 0.3282 - val_loss: 2.2087 - val_mae: 0.9184 - val_mse: 2.0130
# Epoch 40/100
# 39/39 [==============================] - 10s 252ms/step - loss: 0.3251 - mae: 0.2856 - mse: 0.3251 - val_loss: 1.4095 - val_mae: 0.9696 - val_mse: 2.1728
# Epoch 41/100
# 39/39 [==============================] - 9s 243ms/step - loss: 0.3728 - mae: 0.3113 - mse: 0.3728 - val_loss: 2.6430 - val_mae: 0.9491 - val_mse: 2.0614
# Epoch 42/100
# 39/39 [==============================] - 9s 242ms/step - loss: 0.3022 - mae: 0.2900 - mse: 0.3022 - val_loss: 4.7327 - val_mae: 1.0477 - val_mse: 2.5055
# Epoch 43/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.2913 - mae: 0.2899 - mse: 0.2913 - val_loss: 1.5163 - val_mae: 1.0665 - val_mse: 2.5832
# Epoch 44/100
# 39/39 [==============================] - 9s 237ms/step - loss: 0.2956 - mae: 0.2906 - mse: 0.2956 - val_loss: 2.3237 - val_mae: 0.9867 - val_mse: 2.2663
# Epoch 45/100
# 39/39 [==============================] - 9s 242ms/step - loss: 0.2980 - mae: 0.2902 - mse: 0.2980 - val_loss: 1.2345 - val_mae: 0.9668 - val_mse: 2.1463
# Epoch 46/100
# 39/39 [==============================] - 9s 239ms/step - loss: 0.3173 - mae: 0.2973 - mse: 0.3173 - val_loss: 2.4614 - val_mae: 0.9864 - val_mse: 2.2710
# Epoch 47/100
# 39/39 [==============================] - 9s 241ms/step - loss: 0.2927 - mae: 0.2780 - mse: 0.2927 - val_loss: 1.4661 - val_mae: 1.0072 - val_mse: 2.3874
# Epoch 48/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.2680 - mae: 0.2760 - mse: 0.2680 - val_loss: 3.1356 - val_mae: 1.1133 - val_mse: 2.8276
# Epoch 49/100
# 39/39 [==============================] - 10s 254ms/step - loss: 0.2819 - mae: 0.2844 - mse: 0.2819 - val_loss: 2.5891 - val_mae: 0.9395 - val_mse: 2.0536
# Epoch 50/100
# 39/39 [==============================] - 9s 242ms/step - loss: 0.2554 - mae: 0.2752 - mse: 0.2554 - val_loss: 1.5330 - val_mae: 0.9884 - val_mse: 2.1843
# Epoch 51/100
# 39/39 [==============================] - 9s 242ms/step - loss: 0.3009 - mae: 0.2900 - mse: 0.3009 - val_loss: 2.8890 - val_mae: 1.0773 - val_mse: 2.5847
# Epoch 52/100
# 39/39 [==============================] - 9s 241ms/step - loss: 0.2560 - mae: 0.2688 - mse: 0.2560 - val_loss: 2.4284 - val_mae: 0.9971 - val_mse: 2.2782
# Epoch 53/100
# 39/39 [==============================] - 9s 240ms/step - loss: 0.2893 - mae: 0.2855 - mse: 0.2893 - val_loss: 2.0874 - val_mae: 1.1078 - val_mse: 2.7281
# Epoch 54/100
# 39/39 [==============================] - 9s 241ms/step - loss: 0.1991 - mae: 0.2406 - mse: 0.1991 - val_loss: 2.5003 - val_mae: 1.0417 - val_mse: 2.5324
# Epoch 55/100
# 39/39 [==============================] - 9s 238ms/step - loss: 0.2372 - mae: 0.2505 - mse: 0.2372 - val_loss: 2.2821 - val_mae: 1.1365 - val_mse: 2.9449
# Epoch 56/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.2220 - mae: 0.2526 - mse: 0.2220 - val_loss: 2.5160 - val_mae: 1.0378 - val_mse: 2.4500
# Epoch 57/100
# 39/39 [==============================] - 10s 255ms/step - loss: 0.2111 - mae: 0.2455 - mse: 0.2111 - val_loss: 2.4975 - val_mae: 1.2366 - val_mse: 3.3983
# Epoch 58/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.2067 - mae: 0.2379 - mse: 0.2067 - val_loss: 3.2877 - val_mae: 1.2485 - val_mse: 3.3978
# Epoch 59/100
# 39/39 [==============================] - 10s 268ms/step - loss: 0.1886 - mae: 0.2287 - mse: 0.1886 - val_loss: 3.0498 - val_mae: 1.1616 - val_mse: 3.0884
# Epoch 60/100
# 39/39 [==============================] - 10s 254ms/step - loss: 0.1567 - mae: 0.2116 - mse: 0.1567 - val_loss: 3.9578 - val_mae: 1.3962 - val_mse: 4.1227
# Epoch 61/100
# 39/39 [==============================] - 10s 256ms/step - loss: 0.1720 - mae: 0.2262 - mse: 0.1720 - val_loss: 5.9008 - val_mae: 1.4481 - val_mse: 4.6101
# Epoch 62/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.1832 - mae: 0.2234 - mse: 0.1832 - val_loss: 2.6691 - val_mae: 1.3969 - val_mse: 4.1913
# Epoch 63/100
# 39/39 [==============================] - 9s 242ms/step - loss: 0.1668 - mae: 0.2218 - mse: 0.1668 - val_loss: 3.8555 - val_mae: 1.4491 - val_mse: 4.6443
# Epoch 64/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1655 - mae: 0.2199 - mse: 0.1655 - val_loss: 3.6167 - val_mae: 1.3941 - val_mse: 4.2424
# Epoch 65/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1600 - mae: 0.2123 - mse: 0.1600 - val_loss: 5.1878 - val_mae: 1.4032 - val_mse: 4.3156
# Epoch 66/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.1644 - mae: 0.2149 - mse: 0.1644 - val_loss: 5.9270 - val_mae: 1.5712 - val_mse: 5.2724
# Epoch 67/100
# 39/39 [==============================] - 10s 250ms/step - loss: 0.2034 - mae: 0.2266 - mse: 0.2034 - val_loss: 4.7985 - val_mae: 1.4489 - val_mse: 4.4453
# Epoch 68/100
# 39/39 [==============================] - 10s 252ms/step - loss: 0.1271 - mae: 0.1880 - mse: 0.1271 - val_loss: 3.6993 - val_mae: 1.3751 - val_mse: 4.1387
# Epoch 69/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1713 - mae: 0.2101 - mse: 0.1713 - val_loss: 4.6496 - val_mae: 1.3908 - val_mse: 4.2068
# Epoch 70/100
# 39/39 [==============================] - 10s 250ms/step - loss: 0.1846 - mae: 0.2195 - mse: 0.1846 - val_loss: 3.4121 - val_mae: 1.3664 - val_mse: 4.0613
# Epoch 71/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.1312 - mae: 0.1907 - mse: 0.1312 - val_loss: 4.2723 - val_mae: 1.4178 - val_mse: 4.3781
# Epoch 72/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1180 - mae: 0.1802 - mse: 0.1180 - val_loss: 3.2816 - val_mae: 1.2948 - val_mse: 3.7136
# Epoch 73/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1564 - mae: 0.1979 - mse: 0.1564 - val_loss: 7.1945 - val_mae: 1.4095 - val_mse: 4.2557
# Epoch 74/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1513 - mae: 0.1979 - mse: 0.1513 - val_loss: 3.5993 - val_mae: 1.5506 - val_mse: 5.0976
# Epoch 75/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1497 - mae: 0.2015 - mse: 0.1497 - val_loss: 4.4821 - val_mae: 1.4878 - val_mse: 4.8491
# Epoch 76/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1709 - mae: 0.2016 - mse: 0.1709 - val_loss: 3.6890 - val_mae: 1.4159 - val_mse: 4.3952
# Epoch 77/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.1506 - mae: 0.1962 - mse: 0.1506 - val_loss: 3.9765 - val_mae: 1.4990 - val_mse: 4.7941
# Epoch 78/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1310 - mae: 0.1846 - mse: 0.1310 - val_loss: 4.4191 - val_mae: 1.3717 - val_mse: 4.1179
# Epoch 79/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1560 - mae: 0.1981 - mse: 0.1560 - val_loss: 5.7793 - val_mae: 1.6168 - val_mse: 5.5902
# Epoch 80/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1255 - mae: 0.1839 - mse: 0.1255 - val_loss: 5.0285 - val_mae: 1.3951 - val_mse: 4.2305
# Epoch 81/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1240 - mae: 0.1781 - mse: 0.1240 - val_loss: 4.4750 - val_mae: 1.4066 - val_mse: 4.3412
# Epoch 82/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1325 - mae: 0.1830 - mse: 0.1325 - val_loss: 3.4177 - val_mae: 1.4624 - val_mse: 4.6758
# Epoch 83/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1438 - mae: 0.1932 - mse: 0.1438 - val_loss: 4.3133 - val_mae: 1.4054 - val_mse: 4.3356
# Epoch 84/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1159 - mae: 0.1728 - mse: 0.1159 - val_loss: 4.7605 - val_mae: 1.5928 - val_mse: 5.4152
# Epoch 85/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1428 - mae: 0.1863 - mse: 0.1428 - val_loss: 3.5220 - val_mae: 1.4628 - val_mse: 4.6738
# Epoch 86/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1313 - mae: 0.1836 - mse: 0.1313 - val_loss: 4.1007 - val_mae: 1.3990 - val_mse: 4.2544
# Epoch 87/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1049 - mae: 0.1647 - mse: 0.1049 - val_loss: 4.9583 - val_mae: 1.4355 - val_mse: 4.5430
# Epoch 88/100
# 39/39 [==============================] - 10s 248ms/step - loss: 0.1335 - mae: 0.1798 - mse: 0.1335 - val_loss: 3.5543 - val_mae: 1.2970 - val_mse: 3.6590
# Epoch 89/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0895 - mae: 0.1565 - mse: 0.0895 - val_loss: 4.2255 - val_mae: 1.3912 - val_mse: 4.1856
# Epoch 90/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1332 - mae: 0.1749 - mse: 0.1332 - val_loss: 3.7594 - val_mae: 1.3997 - val_mse: 4.2334
# Epoch 91/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1260 - mae: 0.1801 - mse: 0.1260 - val_loss: 2.6030 - val_mae: 1.2937 - val_mse: 3.6446
# Epoch 92/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1167 - mae: 0.1731 - mse: 0.1167 - val_loss: 2.5416 - val_mae: 1.2595 - val_mse: 3.4785
# Epoch 93/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1278 - mae: 0.1792 - mse: 0.1278 - val_loss: 4.1710 - val_mae: 1.1951 - val_mse: 3.1668
# Epoch 94/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1112 - mae: 0.1756 - mse: 0.1112 - val_loss: 2.4448 - val_mae: 0.8422 - val_mse: 1.9475
# Epoch 95/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1177 - mae: 0.1720 - mse: 0.1177 - val_loss: 2.2764 - val_mae: 1.1905 - val_mse: 3.2290
# Epoch 96/100
# 39/39 [==============================] - 10s 249ms/step - loss: 0.0894 - mae: 0.1569 - mse: 0.0894 - val_loss: 2.8409 - val_mae: 1.2003 - val_mse: 3.2035
# Epoch 97/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0905 - mae: 0.1521 - mse: 0.0905 - val_loss: 3.7594 - val_mae: 1.0115 - val_mse: 2.7450
# Epoch 98/100
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0869 - mae: 0.1540 - mse: 0.0869 - val_loss: 1.7602 - val_mae: 0.9038 - val_mse: 2.0234
# Epoch 99/100
# 39/39 [==============================] - 10s 246ms/step - loss: 0.1166 - mae: 0.1613 - mse: 0.1166 - val_loss: 1.6315 - val_mae: 0.7760 - val_mse: 1.6901
# Epoch 100/100
# 39/39 [==============================] - 10s 245ms/step - loss: 0.0856 - mae: 0.1551 - mse: 0.0856 - val_loss: 1.9884 - val_mae: 0.9478 - val_mse: 2.4415

# %%
net.train(train_loader, val_loader, train_steps=train_steps, valid_steps=val_steps, epochs=20)
# Out:
# Epoch 1/20
# 39/39 [==============================] - 20s 504ms/step - loss: 0.0763 - mae: 0.1440 - mse: 0.0763 - val_loss: 0.8884 - val_mae: 0.7508 - val_mse: 1.9546
# Epoch 2/20
# 39/39 [==============================] - 10s 244ms/step - loss: 0.0925 - mae: 0.1540 - mse: 0.0925 - val_loss: 0.7556 - val_mae: 0.5477 - val_mse: 0.9095
# Epoch 3/20
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0734 - mae: 0.1404 - mse: 0.0734 - val_loss: 1.9137 - val_mae: 0.6538 - val_mse: 1.7076
# Epoch 4/20
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0735 - mae: 0.1388 - mse: 0.0735 - val_loss: 1.8763 - val_mae: 0.6600 - val_mse: 1.3819
# Epoch 5/20
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0889 - mae: 0.1495 - mse: 0.0889 - val_loss: 3.0644 - val_mae: 1.0666 - val_mse: 3.7461
# Epoch 6/20
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0976 - mae: 0.1545 - mse: 0.0976 - val_loss: 0.8056 - val_mae: 0.4309 - val_mse: 0.6932
# Epoch 7/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0752 - mae: 0.1340 - mse: 0.0752 - val_loss: 1.4885 - val_mae: 0.6304 - val_mse: 2.3449
# Epoch 8/20
# 39/39 [==============================] - 10s 248ms/step - loss: 0.0895 - mae: 0.1428 - mse: 0.0895 - val_loss: 1.2874 - val_mae: 0.5829 - val_mse: 1.0258
# Epoch 9/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.1004 - mae: 0.1504 - mse: 0.1004 - val_loss: 2.3501 - val_mae: 0.8299 - val_mse: 2.3040
# Epoch 10/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0800 - mae: 0.1392 - mse: 0.0800 - val_loss: 2.1766 - val_mae: 0.6090 - val_mse: 1.3725
# Epoch 11/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0824 - mae: 0.1418 - mse: 0.0824 - val_loss: 4.1824 - val_mae: 1.0953 - val_mse: 3.6479
# Epoch 12/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0709 - mae: 0.1333 - mse: 0.0709 - val_loss: 1.2042 - val_mae: 0.5118 - val_mse: 1.2695
# Epoch 13/20
# 39/39 [==============================] - 10s 248ms/step - loss: 0.0574 - mae: 0.1221 - mse: 0.0574 - val_loss: 3.1758 - val_mae: 0.8545 - val_mse: 2.6279
# Epoch 14/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0547 - mae: 0.1245 - mse: 0.0547 - val_loss: 1.2272 - val_mae: 0.4047 - val_mse: 0.5831
# Epoch 15/20
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0652 - mae: 0.1330 - mse: 0.0652 - val_loss: 0.9046 - val_mae: 0.4313 - val_mse: 0.8628
# Epoch 16/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0841 - mae: 0.1403 - mse: 0.0841 - val_loss: 0.3798 - val_mae: 0.4337 - val_mse: 0.7413
# Epoch 17/20
# 39/39 [==============================] - 10s 247ms/step - loss: 0.0572 - mae: 0.1249 - mse: 0.0572 - val_loss: 0.7985 - val_mae: 0.8916 - val_mse: 4.0468
# Epoch 18/20
# 39/39 [==============================] - 10s 246ms/step - loss: 0.0602 - mae: 0.1254 - mse: 0.0602 - val_loss: 1.6049 - val_mae: 0.4966 - val_mse: 1.0940
# Epoch 19/20
# 39/39 [==============================] - 10s 257ms/step - loss: 0.0520 - mae: 0.1186 - mse: 0.0520 - val_loss: 3.7462 - val_mae: 0.5668 - val_mse: 1.5891
# Epoch 20/20
# 39/39 [==============================] - 10s 251ms/step - loss: 0.0666 - mae: 0.1294 - mse: 0.0666 - val_loss: 1.8528 - val_mae: 0.8147 - val_mse: 2.7638

# %%
import matplotlib.pyplot as plt

plt.imshow(train_loader[1][0][0][:, :, 1])

# %%
import numpy as np

np.random.rand()
# Out:
# 0.6829859484989269

# %%
train_loader[2][1][5]
# Out:
# array([0.91394497, 1.60615659, 0.12762216, 0.        , 0.        ,
#        0.        ])

# %%
train_steps = train_loader.get_steps()
val_steps = val_loader.get_steps()

model = net.model

model.compile(optimizer='rmsprop', loss='mse', metrics=['mae', 'mse'])
history = model.fit_generator(train_loader, validation_data=val_loader,
                                        steps_per_epoch=train_steps, validation_steps=val_steps,
                                        epochs=3)
# Out:
# Epoch 1/3
# 65/65 [==============================] - 26s 397ms/step - loss: 10.7035 - mae: 1.2284 - mse: 10.7035 - val_loss: 81131240.0000 - val_mae: 8061.1055 - val_mse: 147578368.0000
# Epoch 2/3
# 65/65 [==============================] - 15s 226ms/step - loss: 0.9429 - mae: 0.6280 - mse: 0.9429 - val_loss: 0.8863 - val_mae: 0.6716 - val_mse: 0.9983
# Epoch 3/3
# 65/65 [==============================] - 14s 223ms/step - loss: 0.8871 - mae: 0.5855 - mse: 0.8871 - val_loss: 1731.7941 - val_mae: 27.5009 - val_mse: 3177.5229

# %%
train_steps = train_loader.get_steps()
val_steps = val_loader.get_steps()

net.train(train_loader, val_loader, train_steps=train_steps, valid_steps=val_steps, epochs=3)
# Out:
# Epoch 1/3
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-3-b21a27647d3a> in <module>
#       2 val_steps = val_loader.get_steps()
#       3
# ----> 4 net.train(train_loader, val_loader, train_steps=train_steps, valid_steps=val_steps, epochs=3)
#
# ~/ws/repos/sc_odom/q10Net.py in train(self, train_loader, val_loader, train_steps, valid_steps, epochs)
#     125         self.history = self.model.fit_generator(train_loader, validation_data=val_loader,
#     126                                                 steps_per_epoch=train_steps, validation_steps=valid_steps,
# --> 127                                                 epochs=epochs)
#     128         plot_history(self.history)
#     129
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# ~/.pyenv/versions/pcl/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[10,256,80,180] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradients/bn2b_branch2c/cond_grad/StatelessIf/then/_1952/zeros_like_0}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_keras_scratch_graph_37524]
#
# Function call stack:
# keras_scratch_graph

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# train, validation Datagenerator 클래스를  각각 생성합니다.
train_gen = DataGenerator(train_ids, train_path, mask_path, img_size=image_size, batch_size=batch_size)
valid_gen = DataGenerator(valid_ids, train_path, mask_path, img_size=image_size, batch_size=batch_size)
# 여기서 ids, train_path, mask_path는 os.path.join(id, train_path)이런 식으로 경로로 결합하여, 최종적인 이미지의 경로가 됩니다. 이 경로는 앞서 구현한 DataGenerator클래스에서 이미지와 마스크를 불러들이는데 사용됩니다.

print("total training batches: ", len(train_gen))
print("total validaton batches: ", len(valid_gen))
train_steps = len(train_ids) // batch_size
valid_steps = len(valid_ids) // batch_size

BACKBONE = 'resnet34'
#preprocess_input = sm.get_preprocessing(BACKBONE)

# define model
model = sm.Unet(BACKBONE, encoder_weights='imagenet')

optimizer = optimizers.Adam(lr=lr, decay=1e-5)
model.compile(
    optimizer=optimizer,
    loss=sm.losses.bce_dice_loss,
    metrics=[sm.metrics.iou_score],
)

# fit model
set_trainable(model)
model.fit_generator(generator=train_gen, validation_data=valid_gen,
                    steps_per_epoch=train_steps, validation_steps=valid_steps,
                    epochs=epochs)
